# %%
# import library
import pandas as pd
from matplotlib import pyplot as plt
from collections import Counter

# %%
plt.style.use('fivethirtyeight')

data = pd.read_csv('data.csv')
ids = data['Responder_id']
lang_responses = data['LanguagesWorkedWith']


language_counter = Counter()

for response in lang_responses:
    language_counter.update(response.split(';'))

print(language_counter.most_common(15))
lang_most_15_common = language_counter.most_common(15)
# Out:
# [('JavaScript', 59219), ('HTML/CSS', 55466), ('SQL', 47544), ('Python', 36443), ('Java', 35917), ('Bash/Shell/PowerShell', 31991), ('C#', 27097), ('PHP', 23030), ('C++', 20524), ('TypeScript', 18523), ('C', 18017), ('Other(s):', 7920), ('Ruby', 7331), ('Go', 7201), ('Assembly', 5833)]

# %%
languages, popularity = zip(*lang_most_15_common)
languages = list(languages)
popularity = list(popularity)

# %%
languages.reverse()
popularity.reverse()

plt.barh(languages, popularity) # Change to horizontal bar chart
plt.title("Most popular languages")
# plt.ylabel("Programming Languages")
plt.xlabel("Number of people who use")

plt.tight_layout()

plt.savefig("figure/bar_chart_2.png")
plt.show()
